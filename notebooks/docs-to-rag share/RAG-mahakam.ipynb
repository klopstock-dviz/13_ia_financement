# %%
# créer un nouvel env conda à partir du terminal
# conda create --name pathrag python=3.10
# installer ollama: https://www.ollama.com/download

# installer les dépendences
# %pip install -r requirements.txt
# intsaller le modème d'OllamaEmbeddings
# !ollama pull nomic-embed-text
# créer une clé api sur openrouter pour utiliser des llm gratuitement
# Out:
# Requirement already satisfied: accelerate in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (1.8.1)
# Requirement already satisfied: aioboto3 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (15.0.0)
# Requirement already satisfied: aiohttp in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (3.12.13)
# Requirement already satisfied: graspologic in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (3.4.1)
# Requirement already satisfied: hnswlib in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (0.8.0)
# Requirement already satisfied: nano-vectordb in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (0.0.4.3)
# Requirement already satisfied: neo4j in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (5.28.1)
# Requirement already satisfied: networkx in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (3.4.2)
# Requirement already satisfied: ollama in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (0.5.1)
# Requirement already satisfied: openai in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (1.93.0)
# Requirement already satisfied: oracledb in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (3.2.0)
# Requirement already satisfied: pymilvus in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (2.5.11)
# Requirement already satisfied: pymongo in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (4.13.2)
# Requirement already satisfied: pymysql in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (1.1.1)
# Requirement already satisfied: pyvis in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 18)) (0.3.2)
# Requirement already satisfied: sqlalchemy in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 20)) (2.0.41)
# Requirement already satisfied: tenacity in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 21)) (9.1.2)
# Requirement already satisfied: tiktoken in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 25)) (0.9.0)
# Requirement already satisfied: torch in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 26)) (2.7.1)
# Requirement already satisfied: transformers in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (4.53.0)
# Requirement already satisfied: xxhash in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 28)) (3.5.0)
# Requirement already satisfied: python-dotenv in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 32)) (1.1.1)
# Requirement already satisfied: pandas in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 33)) (2.3.0)
# Requirement already satisfied: streamlit in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 34)) (1.46.1)
# Requirement already satisfied: faiss-cpu in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 35)) (1.11.0)
# Requirement already satisfied: sentence-transformers in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 36)) (4.1.0)
# Requirement already satisfied: pypdf==5.4.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 37)) (5.4.0)
# Requirement already satisfied: docx in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 38)) (0.2.4)
# Requirement already satisfied: unstructured in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 39)) (0.18.1)
# Requirement already satisfied: langchain in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 41)) (0.3.26)
# Requirement already satisfied: langchain-openai in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 42)) (0.3.27)
# Requirement already satisfied: langchain-unstructured in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 43)) (0.1.6)
# Requirement already satisfied: langchain-community in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 44)) (0.3.26)
# Requirement already satisfied: langchain-ollama in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 45)) (0.3.3)
# Collecting chromadb (from -r requirements.txt (line 46))
#   Downloading chromadb-1.0.13-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# Requirement already satisfied: psycopg[binary,pool] in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (3.2.9)
# Requirement already satisfied: typing_extensions>=4.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from pypdf==5.4.0->-r requirements.txt (line 37)) (4.14.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from accelerate->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from accelerate->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: psutil in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from accelerate->-r requirements.txt (line 1)) (5.9.1)
# Requirement already satisfied: pyyaml in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from accelerate->-r requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from accelerate->-r requirements.txt (line 1)) (0.33.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from accelerate->-r requirements.txt (line 1)) (0.5.3)
# Requirement already satisfied: aiobotocore==2.23.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from aiobotocore[boto3]==2.23.0->aioboto3->-r requirements.txt (line 2)) (2.23.0)
# Requirement already satisfied: aiofiles>=23.2.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from aioboto3->-r requirements.txt (line 2)) (24.1.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from aiobotocore==2.23.0->aiobotocore[boto3]==2.23.0->aioboto3->-r requirements.txt (line 2)) (0.12.0)
# Requirement already satisfied: botocore<1.38.28,>=1.38.23 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from aiobotocore==2.23.0->aiobotocore[boto3]==2.23.0->aioboto3->-r requirements.txt (line 2)) (1.38.27)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from aiobotocore==2.23.0->aiobotocore[boto3]==2.23.0->aioboto3->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from aiobotocore==2.23.0->aiobotocore[boto3]==2.23.0->aioboto3->-r requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from aiobotocore==2.23.0->aiobotocore[boto3]==2.23.0->aioboto3->-r requirements.txt (line 2)) (6.6.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from aiobotocore==2.23.0->aiobotocore[boto3]==2.23.0->aioboto3->-r requirements.txt (line 2)) (1.17.2)
# Requirement already satisfied: boto3<1.38.28,>=1.38.23 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from aiobotocore[boto3]==2.23.0->aioboto3->-r requirements.txt (line 2)) (1.38.27)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from aiohttp->-r requirements.txt (line 3)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from aiohttp->-r requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from aiohttp->-r requirements.txt (line 3)) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from aiohttp->-r requirements.txt (line 3)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from aiohttp->-r requirements.txt (line 3)) (1.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from aiohttp->-r requirements.txt (line 3)) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from aiohttp->-r requirements.txt (line 3)) (1.20.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from boto3<1.38.28,>=1.38.23->aiobotocore[boto3]==2.23.0->aioboto3->-r requirements.txt (line 2)) (0.13.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from botocore<1.38.28,>=1.38.23->aiobotocore==2.23.0->aiobotocore[boto3]==2.23.0->aioboto3->-r requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: six>=1.5 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore==2.23.0->aiobotocore[boto3]==2.23.0->aioboto3->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: idna>=2.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from yarl<2.0,>=1.17.0->aiohttp->-r requirements.txt (line 3)) (3.10)
# Requirement already satisfied: POT<0.10,>=0.9 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from graspologic->-r requirements.txt (line 6)) (0.9.5)
# Requirement already satisfied: anytree<3.0.0,>=2.12.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from graspologic->-r requirements.txt (line 6)) (2.13.0)
# Requirement already satisfied: beartype<0.19.0,>=0.18.5 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from graspologic->-r requirements.txt (line 6)) (0.18.5)
# Requirement already satisfied: gensim<5.0.0,>=4.3.2 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from graspologic->-r requirements.txt (line 6)) (4.3.3)
# Requirement already satisfied: graspologic-native<2.0.0,>=1.2.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from graspologic->-r requirements.txt (line 6)) (1.2.5)
# Requirement already satisfied: hyppo<0.5.0,>=0.4.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from graspologic->-r requirements.txt (line 6)) (0.4.0)
# Requirement already satisfied: joblib<2.0.0,>=1.4.2 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from graspologic->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: matplotlib<4.0.0,>=3.8.4 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from graspologic->-r requirements.txt (line 6)) (3.10.3)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.4.2 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from graspologic->-r requirements.txt (line 6)) (1.7.0)
# Requirement already satisfied: scipy==1.12.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from graspologic->-r requirements.txt (line 6)) (1.12.0)
# Requirement already satisfied: seaborn<0.14.0,>=0.13.2 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from graspologic->-r requirements.txt (line 6)) (0.13.2)
# Requirement already satisfied: statsmodels<0.15.0,>=0.14.2 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from graspologic->-r requirements.txt (line 6)) (0.14.4)
# Requirement already satisfied: umap-learn<0.6.0,>=0.5.6 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from graspologic->-r requirements.txt (line 6)) (0.5.7)
# Requirement already satisfied: smart-open>=1.8.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from gensim<5.0.0,>=4.3.2->graspologic->-r requirements.txt (line 6)) (7.1.0)
# Requirement already satisfied: numba>=0.46 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from hyppo<0.5.0,>=0.4.0->graspologic->-r requirements.txt (line 6)) (0.61.2)
# Requirement already satisfied: autograd>=1.3 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from hyppo<0.5.0,>=0.4.0->graspologic->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.8.4->graspologic->-r requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.8.4->graspologic->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.8.4->graspologic->-r requirements.txt (line 6)) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.8.4->graspologic->-r requirements.txt (line 6)) (1.4.8)
# Requirement already satisfied: pillow>=8 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.8.4->graspologic->-r requirements.txt (line 6)) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.8.4->graspologic->-r requirements.txt (line 6)) (3.2.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from scikit-learn<2.0.0,>=1.4.2->graspologic->-r requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from statsmodels<0.15.0,>=0.14.2->graspologic->-r requirements.txt (line 6)) (1.0.1)
# Requirement already satisfied: pynndescent>=0.5 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from umap-learn<0.6.0,>=0.5.6->graspologic->-r requirements.txt (line 6)) (0.5.13)
# Requirement already satisfied: tqdm in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from umap-learn<0.6.0,>=0.5.6->graspologic->-r requirements.txt (line 6)) (4.67.1)
# Requirement already satisfied: pytz in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from neo4j->-r requirements.txt (line 9)) (2025.2)
# Requirement already satisfied: httpx>=0.27 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from ollama->-r requirements.txt (line 11)) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from ollama->-r requirements.txt (line 11)) (2.11.7)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from openai->-r requirements.txt (line 12)) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from openai->-r requirements.txt (line 12)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from openai->-r requirements.txt (line 12)) (0.10.0)
# Requirement already satisfied: sniffio in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from openai->-r requirements.txt (line 12)) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: certifi in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from httpx>=0.27->ollama->-r requirements.txt (line 11)) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from httpx>=0.27->ollama->-r requirements.txt (line 11)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27->ollama->-r requirements.txt (line 11)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from pydantic>=2.9->ollama->-r requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from pydantic>=2.9->ollama->-r requirements.txt (line 11)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from pydantic>=2.9->ollama->-r requirements.txt (line 11)) (0.4.1)
# Requirement already satisfied: cryptography>=3.2.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from oracledb->-r requirements.txt (line 13)) (45.0.4)
# Requirement already satisfied: psycopg-binary==3.2.9 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from psycopg[binary,pool]->-r requirements.txt (line 14)) (3.2.9)
# Requirement already satisfied: psycopg-pool in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from psycopg[binary,pool]->-r requirements.txt (line 14)) (3.2.6)
# Requirement already satisfied: setuptools>69 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from pymilvus->-r requirements.txt (line 15)) (78.1.1)
# Requirement already satisfied: grpcio<=1.67.1,>=1.49.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from pymilvus->-r requirements.txt (line 15)) (1.67.1)
# Requirement already satisfied: protobuf>=3.20.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from pymilvus->-r requirements.txt (line 15)) (6.31.1)
# Requirement already satisfied: ujson>=2.0.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from pymilvus->-r requirements.txt (line 15)) (5.10.0)
# Requirement already satisfied: milvus-lite>=2.4.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from pymilvus->-r requirements.txt (line 15)) (2.5.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from pymongo->-r requirements.txt (line 16)) (2.7.0)
# Requirement already satisfied: ipython>=5.3.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from pyvis->-r requirements.txt (line 18)) (8.37.0)
# Requirement already satisfied: jinja2>=2.9.6 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from pyvis->-r requirements.txt (line 18)) (3.1.6)
# Requirement already satisfied: jsonpickle>=1.4.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from pyvis->-r requirements.txt (line 18)) (4.1.1)
# Requirement already satisfied: greenlet>=1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from sqlalchemy->-r requirements.txt (line 20)) (3.2.3)
# Requirement already satisfied: regex>=2022.1.18 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from tiktoken->-r requirements.txt (line 25)) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from tiktoken->-r requirements.txt (line 25)) (2.32.4)
# Requirement already satisfied: filelock in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from torch->-r requirements.txt (line 26)) (3.18.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from torch->-r requirements.txt (line 26)) (1.14.0)
# Requirement already satisfied: fsspec in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from torch->-r requirements.txt (line 26)) (2025.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from torch->-r requirements.txt (line 26)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from torch->-r requirements.txt (line 26)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from torch->-r requirements.txt (line 26)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from torch->-r requirements.txt (line 26)) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from torch->-r requirements.txt (line 26)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from torch->-r requirements.txt (line 26)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from torch->-r requirements.txt (line 26)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from torch->-r requirements.txt (line 26)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from torch->-r requirements.txt (line 26)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from torch->-r requirements.txt (line 26)) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from torch->-r requirements.txt (line 26)) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from torch->-r requirements.txt (line 26)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from torch->-r requirements.txt (line 26)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from torch->-r requirements.txt (line 26)) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from torch->-r requirements.txt (line 26)) (3.3.1)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 27)) (0.21.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from huggingface_hub>=0.21.0->accelerate->-r requirements.txt (line 1)) (1.1.5)
# Requirement already satisfied: tzdata>=2022.7 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 33)) (2025.2)
# Requirement already satisfied: altair<6,>=4.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 34)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 34)) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 34)) (6.1.0)
# Requirement already satisfied: click<9,>=7.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 34)) (8.2.1)
# Requirement already satisfied: pyarrow>=7.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 34)) (20.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 34)) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 34)) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 34)) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 34)) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 34)) (6.1)
# Requirement already satisfied: jsonschema>=3.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 34)) (4.24.0)
# Requirement already satisfied: narwhals>=1.14.2 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 34)) (1.44.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 34)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 34)) (5.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken->-r requirements.txt (line 25)) (3.4.2)
# Requirement already satisfied: lxml in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from docx->-r requirements.txt (line 38)) (6.0.0)
# Requirement already satisfied: chardet in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 39)) (5.2.0)
# Requirement already satisfied: filetype in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 39)) (1.2.0)
# Requirement already satisfied: python-magic in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 39)) (0.4.27)
# Requirement already satisfied: nltk in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 39)) (3.9.1)
# Requirement already satisfied: beautifulsoup4 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 39)) (4.13.4)
# Requirement already satisfied: emoji in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 39)) (2.14.1)
# Requirement already satisfied: dataclasses-json in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 39)) (0.6.7)
# Requirement already satisfied: python-iso639 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 39)) (2025.2.18)
# Requirement already satisfied: langdetect in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 39)) (1.0.9)
# Requirement already satisfied: rapidfuzz in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 39)) (3.13.0)
# Requirement already satisfied: backoff in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 39)) (2.2.1)
# Requirement already satisfied: unstructured-client in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 39)) (0.37.2)
# Requirement already satisfied: python-oxmsg in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 39)) (0.0.2)
# Requirement already satisfied: html5lib in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 39)) (1.1)
# Requirement already satisfied: python-docx>=1.1.2 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from unstructured[docx]->-r requirements.txt (line 40)) (1.2.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 41)) (0.3.66)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 41)) (0.3.8)
# Requirement already satisfied: langsmith>=0.1.17 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 41)) (0.4.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain->-r requirements.txt (line 41)) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain->-r requirements.txt (line 41)) (3.0.0)
# Requirement already satisfied: onnxruntime<=1.19.2,>=1.17.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from langchain-unstructured->-r requirements.txt (line 43)) (1.19.2)
# Requirement already satisfied: coloredlogs in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from onnxruntime<=1.19.2,>=1.17.0->langchain-unstructured->-r requirements.txt (line 43)) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from onnxruntime<=1.19.2,>=1.17.0->langchain-unstructured->-r requirements.txt (line 43)) (25.2.10)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from unstructured-client->unstructured->-r requirements.txt (line 39)) (1.6.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from unstructured-client->unstructured->-r requirements.txt (line 39)) (1.0.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from langchain-community->-r requirements.txt (line 44)) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from langchain-community->-r requirements.txt (line 44)) (0.4.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from dataclasses-json->unstructured->-r requirements.txt (line 39)) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from dataclasses-json->unstructured->-r requirements.txt (line 39)) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured->-r requirements.txt (line 39)) (1.1.0)
# Collecting build>=1.0.3 (from chromadb->-r requirements.txt (line 46))
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Collecting pybase64>=1.4.1 (from chromadb->-r requirements.txt (line 46))
#   Downloading pybase64-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 46))
#   Downloading uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting posthog>=2.4.0 (from chromadb->-r requirements.txt (line 46))
#   Downloading posthog-6.0.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb->-r requirements.txt (line 46))
#   Downloading opentelemetry_api-1.34.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb->-r requirements.txt (line 46))
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.34.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb->-r requirements.txt (line 46))
#   Downloading opentelemetry_sdk-1.34.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting pypika>=0.48.9 (from chromadb->-r requirements.txt (line 46))
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting overrides>=7.3.1 (from chromadb->-r requirements.txt (line 46))
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb->-r requirements.txt (line 46))
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting bcrypt>=4.0.1 (from chromadb->-r requirements.txt (line 46))
#   Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Collecting typer>=0.9.0 (from chromadb->-r requirements.txt (line 46))
#   Downloading typer-0.16.0-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb->-r requirements.txt (line 46))
#   Downloading kubernetes-33.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting mmh3>=4.0.1 (from chromadb->-r requirements.txt (line 46))
#   Downloading mmh3-5.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: orjson>=3.9.12 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from chromadb->-r requirements.txt (line 46)) (3.10.18)
# Collecting rich>=10.11.0 (from chromadb->-r requirements.txt (line 46))
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb->-r requirements.txt (line 46))
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting tomli>=1.1.0 (from build>=1.0.3->chromadb->-r requirements.txt (line 46))
#   Downloading tomli-2.2.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: cffi>=1.14 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from cryptography>=3.2.1->oracledb->-r requirements.txt (line 13)) (1.17.1)
# Requirement already satisfied: pycparser in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from cffi>=1.14->cryptography>=3.2.1->oracledb->-r requirements.txt (line 13)) (2.22)
# Requirement already satisfied: decorator in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->-r requirements.txt (line 18)) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->-r requirements.txt (line 18)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->-r requirements.txt (line 18)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->-r requirements.txt (line 18)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->-r requirements.txt (line 18)) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->-r requirements.txt (line 18)) (2.19.2)
# Requirement already satisfied: stack_data in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->-r requirements.txt (line 18)) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis->-r requirements.txt (line 18)) (5.14.3)
# Requirement already satisfied: wcwidth in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis->-r requirements.txt (line 18)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis->-r requirements.txt (line 18)) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from jinja2>=2.9.6->pyvis->-r requirements.txt (line 18)) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 34)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 34)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 34)) (0.25.1)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 46))
#   Downloading google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 46))
#   Downloading websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 46))
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 46))
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 46))
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Collecting cachetools<7,>=4.0 (from streamlit->-r requirements.txt (line 34))
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 46))
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 46))
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 46))
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from langsmith>=0.1.17->langchain->-r requirements.txt (line 41)) (0.23.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from numba>=0.46->hyppo<0.5.0,>=0.4.0->graspologic->-r requirements.txt (line 6)) (0.44.0)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb->-r requirements.txt (line 46))
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb->-r requirements.txt (line 46))
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 46))
#   Downloading googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.34.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 46))
#   Downloading opentelemetry_exporter_otlp_proto_common-1.34.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.34.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 46))
#   Downloading opentelemetry_proto-1.34.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting protobuf>=3.20.0 (from pymilvus->-r requirements.txt (line 15))
#   Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting opentelemetry-semantic-conventions==0.55b1 (from opentelemetry-sdk>=1.2.0->chromadb->-r requirements.txt (line 46))
#   Downloading opentelemetry_semantic_conventions-0.55b1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis->-r requirements.txt (line 18)) (0.7.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->chromadb->-r requirements.txt (line 46))
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb->-r requirements.txt (line 46))
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 26)) (1.3.0)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb->-r requirements.txt (line 46))
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 46))
#   Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 46))
#   Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 46))
#   Downloading watchfiles-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 46))
#   Downloading websockets-15.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: soupsieve>1.2 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from beautifulsoup4->unstructured->-r requirements.txt (line 39)) (2.7)
# Requirement already satisfied: humanfriendly>=9.1 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from coloredlogs->onnxruntime<=1.19.2,>=1.17.0->langchain-unstructured->-r requirements.txt (line 43)) (10.0)
# Requirement already satisfied: webencodings in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from html5lib->unstructured->-r requirements.txt (line 39)) (0.5.1)
# Requirement already satisfied: olefile in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from python-oxmsg->unstructured->-r requirements.txt (line 39)) (0.47)
# Requirement already satisfied: executing>=1.2.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from stack_data->ipython>=5.3.0->pyvis->-r requirements.txt (line 18)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from stack_data->ipython>=5.3.0->pyvis->-r requirements.txt (line 18)) (3.0.0)
# Requirement already satisfied: pure_eval in /home/chougar/miniconda3/envs/pathrag/lib/python3.10/site-packages (from stack_data->ipython>=5.3.0->pyvis->-r requirements.txt (line 18)) (0.2.3)
# Downloading chromadb-1.0.13-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 73.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl (284 kB)
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading kubernetes-33.1.0-py2.py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 51.2 MB/s eta 0:00:00
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading mmh3-5.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (99 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Downloading opentelemetry_api-1.34.1-py3-none-any.whl (65 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.34.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.34.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.34.1-py3-none-any.whl (55 kB)
# Downloading googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Downloading opentelemetry_sdk-1.34.1-py3-none-any.whl (118 kB)
# Downloading opentelemetry_semantic_conventions-0.55b1-py3-none-any.whl (196 kB)
# Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-6.0.0-py3-none-any.whl (104 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading pybase64-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (68 kB)
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading tomli-2.2.1-py3-none-any.whl (14 kB)
# Downloading typer-0.16.0-py3-none-any.whl (46 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
# Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
# Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 54.3 MB/s eta 0:00:00
# Downloading watchfiles-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (453 kB)
# Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Downloading websockets-15.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (181 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53803 sha256=c303a63a1a1caa6a0db57c44111d4901df44466c9d334c8cf9f6da3dac4476dc
#   Stored in directory: /home/chougar/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, durationpy, zipp, websockets, websocket-client, uvloop, uvicorn, tomli, shellingham, pyproject_hooks, pybase64, pyasn1, protobuf, overrides, oauthlib, mmh3, mdurl, importlib-resources, httptools, cachetools, bcrypt, rsa, requests-oauthlib, pyasn1-modules, posthog, opentelemetry-proto, markdown-it-py, importlib-metadata, googleapis-common-protos, build, watchfiles, rich, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, google-auth, typer, opentelemetry-semantic-conventions, kubernetes, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, chromadb
#   Attempting uninstall: protobuf╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/41 [pyasn1]ets]
#     Found existing installation: protobuf 6.31.1m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/41 [pyasn1]
#     Uninstalling protobuf-6.31.1:38;2;249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/41 [pyasn1]
#       Successfully uninstalled protobuf-6.31.114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/41 [pyasn1]
#   Attempting uninstall: cachetools╸━━━━━━━━━━━━━━━━━━━━━━━━━━ 14/41 [oauthlib]
#     Found existing installation: cachetools 6.1.014m╸━━━━━━━━━━━━━━━━━━━━━━━━━━ 14/41 [oauthlib]
#     Uninstalling cachetools-6.1.0:╸━━━━━━━━━━━━━━━━━━━━━━━━━━ 14/41 [oauthlib]
#       Successfully uninstalled cachetools-6.1.0;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━ 14/41 [oauthlib]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41/41 [chromadb] [chromadb] [kubernetes]try-semantic-conventions]
# Successfully installed bcrypt-4.3.0 build-1.2.2.post1 cachetools-5.5.2 chromadb-1.0.13 durationpy-0.10 google-auth-2.40.3 googleapis-common-protos-1.70.0 httptools-0.6.4 importlib-metadata-8.7.0 importlib-resources-6.5.2 kubernetes-33.1.0 markdown-it-py-3.0.0 mdurl-0.1.2 mmh3-5.1.0 oauthlib-3.3.1 opentelemetry-api-1.34.1 opentelemetry-exporter-otlp-proto-common-1.34.1 opentelemetry-exporter-otlp-proto-grpc-1.34.1 opentelemetry-proto-1.34.1 opentelemetry-sdk-1.34.1 opentelemetry-semantic-conventions-0.55b1 overrides-7.7.0 posthog-6.0.0 protobuf-5.29.5 pyasn1-0.6.1 pyasn1-modules-0.4.2 pybase64-1.4.1 pypika-0.48.9 pyproject_hooks-1.2.0 requests-oauthlib-2.0.0 rich-14.0.0 rsa-4.9.1 shellingham-1.5.4 tomli-2.2.1 typer-0.16.0 uvicorn-0.35.0 uvloop-0.21.0 watchfiles-1.1.0 websocket-client-1.8.0 websockets-15.0.1 zipp-3.23.0
# Note: you may need to restart the kernel to use updated packages.
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest
# pulling 970aa74c0a90: 100% ▕██████████████████▏ 274 MB
# pulling c71d239df917: 100% ▕██████████████████▏  11 KB
# pulling ce4a164fc046: 100% ▕██████████████████▏   17 B
# pulling 31df23ea7daa: 100% ▕██████████████████▏  420 B
# verifying sha256 digest
# writing manifest
# success

# %%
from openai import OpenAI, AsyncOpenAI
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
from langchain_ollama import OllamaEmbeddings
from langchain.schema.document import Document
from pathrag_retriever import create_graphdb, load_existing_graphdb, load_knowledgeGraph_vis
import time

# %%
from langchain.vectorstores import Chroma
from langchain_ollama import OllamaEmbeddings
from langchain_community.retrievers import TFIDFRetriever
from langchain_unstructured import UnstructuredLoader

#========= choix du modèle d'embedding
"""
    Le modèle choisi impacte la qualité du retriever, mais aussi le temps de traitement
    Si le déploiement est prévu sur une VM limitée, un modèle plus petit est nécessaire
    Explorer les comparatifs: https://huggingface.co/spaces/mteb/leaderboard

"""
# Utiliser OllamaEmbeddings avec le modèle local "nomic-embed-text"
embeddings = OllamaEmbeddings(model="nomic-embed-text")



# chargement et fragmentation du doc
filename="PU_P01_PP01.docx"
doc_name="PP mahakam" # nom de doc significatif


# loader = UnstructuredFileLoader(filename)
loader = UnstructuredLoader(filename)

docx_docs = loader.load()
print(f"Loaded {len(docx_docs)} documents from {filename}")


#======== choix des paramètres de fragmentation
"""
    la taille du chunck_size est très important dans l'accès à une info précise
    une plus petite taille permet de cibler de courts passages contenant l'info nécessaire à des réponses précises:
        * lieu du projet
        * dates du projet
        * budget ...    
    l'envoi de passages plus courts au llm évite une dispertion de son attention
"""

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=200,
    length_function=len
)

docs = text_splitter.split_documents(docx_docs)

# Filter out complex metadata (e.g., lists, dicts)
docs = [Document(doc.page_content) for doc in docs]

print(len(docs))

# Conversion des docs en embeddings 
chroma_db = Chroma.from_documents(
    docs,
    embedding=embeddings,
    persist_directory=f'./storage/vector_scores/{doc_name.replace(" ","_")}',
    collection_name=doc_name.replace(" ","_")
)

retriever=chroma_db.as_retriever()

# ...existing code...
all_docs = chroma_db.get()
print(len(all_docs['documents']))  # This will print the total number of docs stored
# ...existing code...
# Out:
# INFO:chromadb.telemetry.product.posthog:Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# ERROR:chromadb.telemetry.product.posthog:Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# ERROR:chromadb.telemetry.product.posthog:Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Loaded 533 documents from PU_P01_PP01.docx
# 590
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/embed "HTTP/1.1 200 OK"
# ERROR:chromadb.telemetry.product.posthog:Failed to send telemetry event CollectionGetEvent: capture() takes 1 positional argument but 3 were given
# 590

# %%
# appliquer nest_asyncio uniquement sur notebook pour corriger l'erreur de loop event
import nest_asyncio
nest_asyncio.apply()

# remetre à plat le text
filename="PU_P01_PP01.docx"
loader = UnstructuredLoader(filename)

docx_docs = loader.load()
text=""
for doc in docx_docs:
    text+=doc.page_content


r=input("Saisir 'C' pour créer un nouveau graphe, 'L' pour charger un graphe existant")

# créer un nouveau graphe
messages=None
if r=='C':
    doc_name=input('Saisir un nom unique pour votre graphe')
    print(f"Le nom de votre graphe est {doc_name}")
    messages= create_graphdb(
        text=text, 
        doc_name=doc_name, # il faut donner un nom unique permettant d'identifier et charger le graph les prochaines fois
    )
# charger un graphe existant
elif r=='L':
    doc_name=input('Saisir le nom du graphe à charger')
    print(f"Le nom de votre graphe est {doc_name}")

    messages=load_existing_graphdb(doc_name)
else:
    print('Option invalide')



if messages:
    pipeline_args={}
    for feedback in messages:
        if isinstance(feedback, str):
            print(feedback)
        elif isinstance(feedback, dict):
            pipeline_args[f"graphrag_pipeline_{doc_name}"]=feedback["pipeline_args"]
# Out:
# INFO:PathRAG:Logger initialized for working directory: /home/chougar/Documents/GitHub/Projet-portail-immo/docs-to-rag share/storage/graph_stores/39a6c98b9231f8b45540c3c6802c80d091e49aed11883eb887fc10dd366d605c
# INFO:PathRAG:Load KV llm_response_cache with 0 data
# INFO:PathRAG:Load KV full_docs with 1 data
# INFO:PathRAG:Load KV text_chunks with 17 data
# INFO:PathRAG:Loaded graph from /home/chougar/Documents/GitHub/Projet-portail-immo/docs-to-rag share/storage/graph_stores/39a6c98b9231f8b45540c3c6802c80d091e49aed11883eb887fc10dd366d605c/graph_chunk_entity_relation.graphml with 464 nodes, 206 edges
# INFO:nano-vectordb:Load (447, 768) data
# INFO:nano-vectordb:Init {'embedding_dim': 768, 'metric': 'cosine', 'storage_file': '/home/chougar/Documents/GitHub/Projet-portail-immo/docs-to-rag share/storage/graph_stores/39a6c98b9231f8b45540c3c6802c80d091e49aed11883eb887fc10dd366d605c/vdb_entities.json'} 447 data
# INFO:nano-vectordb:Load (206, 768) data
# INFO:nano-vectordb:Init {'embedding_dim': 768, 'metric': 'cosine', 'storage_file': '/home/chougar/Documents/GitHub/Projet-portail-immo/docs-to-rag share/storage/graph_stores/39a6c98b9231f8b45540c3c6802c80d091e49aed11883eb887fc10dd366d605c/vdb_relationships.json'} 206 data
# INFO:nano-vectordb:Load (17, 768) data
# INFO:nano-vectordb:Init {'embedding_dim': 768, 'metric': 'cosine', 'storage_file': '/home/chougar/Documents/GitHub/Projet-portail-immo/docs-to-rag share/storage/graph_stores/39a6c98b9231f8b45540c3c6802c80d091e49aed11883eb887fc10dd366d605c/vdb_chunks.json'} 17 data
# Le nom de votre graphe est PP mahakam
#
#         ----------------
#         #### Graph RAG retriever
#         Chargement de la base Graph RAG
#
# **✅ Graph RAG chargé**

# %%
from PathRAG import QueryParam
import asyncio


def stream_pathRAG_response(stream_resp):
    async def stream_response():        
        # Process the async generator
        async for chunk in stream_resp:
            print(chunk or "", end="")



    # Run in Streamlit's existing event loop
    loop = asyncio.get_event_loop()
    loop.run_until_complete(stream_response())


# question="résume ce texte dans sa langue source"
question = "Quels sont les principaux thèmes de ce texte et les questions qui peuvent être posées ?"

resp=pipeline_args[f"graphrag_pipeline_{doc_name}"]["rag"].query(query= question, param=QueryParam(mode="hybrid", stream=True))

stream_pathRAG_response(resp)
# Out:
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:PathRAG:kw_prompt result:
# INFO:PathRAG:```json
# {
#   "high_level_keywords": ["Thèmes principaux", "Analyse de texte", "Compréhension de texte", "Questionnement"],
#   "low_level_keywords": ["Idées clés", "Résumé", "Sujet", "Questions de discussion", "Points importants"]
# }
# ```
# INFO:PathRAG:Local query uses 40 entites, 9 relations, 3 text units
# INFO:PathRAG:Global query uses 45 entites, 40 relations, 3 text units
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# response all ready
#
# ## Principaux thèmes et questions potentielles du texte
#
# Le texte fourni présente un ensemble d'informations concernant un projet de conservation des mangroves, le "NEW MAHAKAM PROJECT", dans la région du Kalimantan (Bornéo, Indonésie). Voici les principaux thèmes qui ressortent, ainsi que des questions qui pourraient être posées à partir de ces données :
#
# **Thèmes principaux:**
#
# *   **Conservation des mangroves :** C'est le thème central, incluant la restauration, la plantation, la protection et la gestion durable des écosystèmes de mangroves.
# *   **Collaboration multipartite :** Le projet s'appuie sur une collaboration importante entre diverses organisations, incluant Planète Urgence (PU), des ONG locales (YML, Pokja Pesisir), des agences gouvernementales, et des groupes communautaires.
# *   **Développement durable et communautaire :** Le projet vise non seulement la restauration écologique, mais également l'amélioration des moyens de subsistance des communautés locales et le renforcement de leur capacité à gérer durablement les ressources naturelles.
# *   **Gouvernance environnementale :** L'importance de la planification, de la coordination, et de l'implication des parties prenantes dans la gestion des ressources est soulignée.
# *   **Capacité organisationnelle & Formation :** Le renforcement des compétences des organisations partenaires (YML, Pokja Pesisir) est un aspect essentiel du projet.
# *   **Importance de la communication et du partage des connaissances :**  Un effort considérable est mis sur la communication interne et externe, la documentation des "leçons apprises", et la diffusion des bonnes pratiques.
# *   **Adaptation aux changements contextuels:** le projet prend en compte les changements liés à la relocalisation de la capitale indonésienne à Kalimantan.
#
# **Questions potentielles découlant des données :**
#
# **Sur le projet et ses objectifs :**
#
# *   Quels sont les indicateurs de succès spécifiques pour évaluer l'impact du projet sur la restauration des mangroves ?
# *   Comment le projet s'assure-t-il de l'implication significative des communautés locales dans la prise de décision et la mise en œuvre des activités ?
# *   Comment le projet répond-il aux défis liés à la conversion des terres et à la concurrence entre les différents usages (aquaculture, agriculture, etc.) dans la région ?
# *   Quel est le rôle de la relocalisation de la capitale indonésienne dans le contexte du projet NEW MAHAKAM et comment le projet s'adapte-t-il à ce changement ?
# *   Quels sont les mécanismes de financement du projet et comment l'assurer une pérennité une fois le financement initial épuisé ?
#
# **Sur les organisations partenaires :**
#
# *   Quelles sont les forces et les faiblesses spécifiques de chaque organisation partenaire (Planète Urgence, YML, Pokja Pesisir) et comment ces forces sont-elles utilisées pour maximiser l'efficacité du projet ?
# *   Comment le projet aborde-t-il l'écart de compétences entre les partenaires (par exemple, le manque d'expérience en reforestation de Pokja Pesisir, le manque de capacité de surveillance de YML) ?
# *   Quel est le rôle exact du Conseil Régional sur le Changement Climatique dans le projet ?
# *   Comment le projet met-il en œuvre une stratégie de durabilité pour s'assurer que les bénéfices du projet persistent après son achèvement ?
#
# **Sur les aspects techniques et environnementaux :**
#
# *   Quels critères sont utilisés pour sélectionner les sites de reforestation et s'assurer de leur pertinence écologique ?
# *   Quelles espèces de mangroves sont plantées et comment sont-elles sélectionnées pour assurer leur adaptation aux conditions locales ?
# *   Comment le projet suit-il la survie des arbres plantés et évalue-t-il l'impact des activités de restauration sur la biodiversité ?
# *   Quelles sont les stratégies mises en place pour atténuer les risques potentiels liés aux changements climatiques (élévation du niveau de la mer, événements climatiques extrêmes) ?
#
# **Sur les aspects sociaux et de gouvernance :**
#
# *   Comment le projet prend-il en compte les questions d'égalité des sexes et s'assure-t-il que les femmes sont pleinement impliquées dans les activités de conservation ?
# *   Comment le projet gère-t-il les conflits potentiels entre les différentes parties prenantes (communautés locales, entreprises, agences gouvernementales) ?
# *    Comment le projet s'aligne-t-il sur les objectifs de développement durable (ODD) des Nations Unies ?
#
#
#
#
# En résumé, le texte est riche en informations et ouvre la voie à de nombreuses investigations sur différents aspects de ce projet ambitieux de conservation des mangroves, de collaboration et de développement durable.

# %%
from langchain.vectorstores import Chroma
from langchain.embeddings import OllamaEmbeddings
from langchain.retrievers import EnsembleRetriever
from langchain.retrievers import TFIDFRetriever
from langchain.schema.document import Document
from openai import OpenAI, AsyncOpenAI
import asyncio
import json
import re

class RAG_hybrid():
    def __init__(self, model):
        self.model=model
        self.retrieved_docs=[]
        self.semantic_retriever_topK=10
        self.sparse_retriever_topK=10
        self.history=[]
        self.llm_client = AsyncOpenAI(
            base_url="https://openrouter.ai/api/v1",
            api_key="clé",
        )
        self.reranker_llm="mistralai/mistral-small-3.1-24b-instruct:free"
        self.reranker_score_thresh=5
        self.reranked_doc=[]

    def semanticRetriever(self):
        # 1. Semantic Retriever (Chroma + OllamaEmbeddings)
        embeddings = OllamaEmbeddings(model="nomic-embed-text")
        chroma_db = Chroma(
            persist_directory=f'./storage/vector_scores/{doc_name.replace(" ","_")}',
            collection_name=doc_name.replace(" ","_"),
            embedding_function=embeddings
        )

        semantic_retriever=chroma_db.as_retriever(search_type="mmr", k=self.semantic_retriever_topK)

        self.chroma_db=chroma_db
        self.semantic_retriever=semantic_retriever
    
    def sparseRetriever(self):
        # 2. Sparse Retriever (TF-IDF)

        # Récupérer TOUS les documents depuis Chroma
        all_data = self.chroma_db.get(include=["documents", "metadatas"])

        # Convertir en liste de `Document` objects pour LangChain
        docs = [
            Document(page_content=text, metadata=meta or {})  # <-- Si meta est None, on met {}
            for text, meta in zip(all_data["documents"], all_data["metadatas"])
        ]

        # Créer le retriever TF-IDF
        sparse_retriever = TFIDFRetriever.from_documents(
            documents=docs,
            k=self.sparse_retriever_topK,
            tfidf_params={"min_df": 1, "ngram_range": (1, 2)}
        )

        self.sparse_retriever= sparse_retriever
    
    def ensembleRetriever(self):
        # 3. Ensemble Retriever (Semantic + Sparse)
        ensemble_retriever = EnsembleRetriever(
            retrievers=[self.semantic_retriever, self.sparse_retriever],
            weights=[0.5, 0.5]
        )

        self.ensemble_retriever=ensemble_retriever

    async def reranker(self, results, query):


        async def llm_eval(doc, query):
            system_prompt="""
                You're an expert assistant in reranking documents against a question.
                Your role is to compare the question with a document and give a score from 0 to 10, where:
                0=document out of context, unable to answer the question
                10=highly relevant document, able to answer the question
                                
                The expected final output is the score in json format
                Example:
                ```json{"score": 5}```
                
                Always end your answer with this format                
            """            
            response = await self.llm_client.chat.completions.create(
                model=self.reranker_llm,
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": f"La question est: {query}\n Le document à évaluer est le suivant\n: {doc}" }
                ],
                temperature=0,
            )
            # Post-process to extract only the JSON part if extra text is present
            content = response.choices[0].message.content
            # Try to extract the JSON block if the model adds extra text
            match = re.search(r"\{.*?\}", content, re.DOTALL)
            if match:
                content = match.group(0)

            # extract score
            score=None
            try:
                score=content.replace("```json", "").replace("```", "")
                
                score= json.loads(score)
                score=score["score"]
            except Exception as e:
                print(e)                
            
            return {"content": doc, "score": score}


        tasks=[llm_eval(doc.page_content, query) for doc in results]
        scored_docs= await asyncio.gather(*tasks)
        i=1

        for doc in scored_docs:
          
            print(f'chunk {i} score: {doc["score"]}')
            i+=1

        filtred_docs=[d for d in scored_docs if d["score"]>=self.reranker_score_thresh]
        # print(f"scored docs; \n{scored_docs}")
        self.reranked_doc=filtred_docs

        return filtred_docs

    async def ask_llm(self, query):
        # 5. Final processing step with an LLM (e.g., OpenAI via OpenRouter)

        # init retrievers
        self.semanticRetriever()
        self.sparseRetriever()
        self.ensembleRetriever()

        # retrieve relevant docs
        results = self.ensemble_retriever.get_relevant_documents(query)
        print(f"Nb of retrieved docs: {len(results)}")

        # rerank
        scored_results=await self.reranker(results, query)
        
        # Concatenate retrieved documents for context
        context = "\n".join([f"Fragment: \n{doc['content']}\n" for doc in scored_results])

        print(f"Context lenght: {len(context.split(' '))} words")
        llm_prompt = f"""
            Answer the question based **only** on the provided context.  

            - If the context contains enough information to provide a complete or partial answer, use it to formulate a detailed and factual response.  
            - If the context lacks relevant information, respond with: "I don't know."  

            ### **Context:**  
            {context}  

            ### **Question:**  
            {query}  

            ### **Answer:**  
            Provide a clear, factual, and well-structured response based on the available context. Avoid speculation or adding external knowledge.  
        """

        llm_completion = await self.llm_client.chat.completions.create(
            model=self.model,
            messages=[
                {"role": "system", "content": "You are an expert in document Q/A and document synthesis"},
                {"role": "user", "content": llm_prompt}
            ],
            temperature=0.2,
            stream=True
        )

        final_answer = ""
        print("Réponse:\n=========")
        async for chunk in llm_completion:
            if hasattr(chunk.choices[0].delta, "content") and chunk.choices[0].delta.content:
                final_answer += chunk.choices[0].delta.content
                print(chunk.choices[0].delta.content, end="", flush=True)
        
        self.history+=[
            {"role": "user", 'content': query},
            {"role": "assistant", "content": final_answer}
        ]
        
        return final_answer


rag_hybrid=RAG_hybrid(model="google/gemma-3-27b-it:free")
# 4. Ask a question
# question = "Quels sont les principaux conseils pour réussir dans l'entrepreneuriat ?"
# question="que faut il absolument éviter pour réussir sa startup ?"
# question="résume ce texte"
results = await rag_hybrid.ask_llm(question)
# Out:
# ERROR:chromadb.telemetry.product.posthog:Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# ERROR:chromadb.telemetry.product.posthog:Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Nb of retrieved docs: 14
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# chunk 1 score: 0
# chunk 2 score: 3
# chunk 3 score: 0
# chunk 4 score: 2
# chunk 5 score: 0
# chunk 6 score: 0
# chunk 7 score: 0
# chunk 8 score: 0
# chunk 9 score: 4
# chunk 10 score: 1
# chunk 11 score: 0
# chunk 12 score: 2
# chunk 13 score: 4
# chunk 14 score: 0
# Context lenght: 1 words
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# Réponse:
# =========
#
# I don't know.
#
# The provided context is empty. Therefore, I cannot identify the main themes of a text or formulate questions about it.
